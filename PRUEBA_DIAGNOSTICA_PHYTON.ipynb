# %% [markdown]
# ##PAR E IMPAR

# %%
numero = int(input("Ingresa un número: "))

if numero % 2 == 0:
    print("El número es par")
else:
    print("El número es impar")

# %% [markdown]
# ##BISIESTO

# %%
año = int(input("Ingresa un año: "))

if (año % 4 == 0 and anio % 100 != 0) or (anio % 400 == 0):
    print("Es un año bisiesto")
else:
    print("No es un año bisiesto")

# %% [markdown]
# ##70 AÑOS

# %%
nombre = input("Ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

if edad >= 70:
    print(nombre + ", pertenece a la tercera edad. Tiene prioridad en la fila.")
else:
    print(nombre + ", no pertenece a la tercera edad.")

# %% [markdown]
# ##EL MAYOR DE 3

# %%
num1 = int(input("Ingresa el primer número: "))
num2 = int(input("Ingresa el segundo número: "))
num3 = int(input("Ingresa el tercer número: "))

mayor = num1

if num2 > mayor:
    mayor = num2
if num3 > mayor:
    mayor = num3

print("El número mayor es:", mayor)

# %% [markdown]
# ##TIPO DE TRIANGULO

# %%
l1 = float(input("Ingresa el primer lado: "))
l2 = float(input("Ingresa el segundo lado: "))
l3 = float(input("Ingresa el tercer lado: "))

if l1 == l2 == l3:
    print("El triángulo es equilátero")
elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
    print("El triángulo es isósceles")
else:
    print("El triángulo es escaleno")
# Out:
# Ingresa el primer lado: 1
# Ingresa el segundo lado: 1
# Ingresa el tercer lado: 1
# El triángulo es equilátero
