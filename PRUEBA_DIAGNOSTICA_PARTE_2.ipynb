# %% [markdown]
# <a href="https://colab.research.google.com/github/Andres3417/PROGCOM-A-2026/blob/main/PRUEBA_DIAGNOSTICA_PARTE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##TABLAS DE MULTIPLICAR HASTA EL 10

# %%
numero = int(input("Ingresa un número: "))

for i in range(1, 11):
    print(numero, "x", i, "=", numero * i)

# %% [markdown]
# ##SUMA DE NUMEROS NATURALES

# %%
n = int(input("Ingresa un número: "))
suma = 0

for i in range(1, n + 1):
    suma += i

print("La suma es:", suma)
# Out:
# Ingresa un número: 10
# La suma es: 55

# %% [markdown]
# ##FACTORIAL DE UN NÚMERO

# %%
n = int(input("Ingresa un número: "))

if n < 0:
    print("No existen factoriales negativos")
else:
    factorial = 1
    for i in range(1, n + 1):
        factorial *= i
    print("El factorial es:", factorial)

# %% [markdown]
# ##NUMEROS PARES HASTA EL 100

# %%
for i in range(1, 101):
    if i % 2 == 0:
        print(i)

# %% [markdown]
# ##SUMA DE DIGITOS

# %%
numero = input("Ingresa un número: ")
suma = 0

for digito in numero:
    suma += int(digito)

print("La suma de los dígitos es:", suma)
# Out:
# Ingresa un número: 23
# La suma de los dígitos es: 5

# %% [markdown]
# ##NÚMERO PRIMO

# %%
numero = int(input("Escribe un número: "))

if numero <= 1:
    print("No es primo")
else:
    es_primo = True

    for i in range(2, numero):
        if numero % i == 0:
            es_primo = False
            break

    if es_primo:
        print("Es primo")
    else:
        print("No es primo")
# Out:
# Escribe un número: 2
# Es primo
