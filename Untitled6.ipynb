# %% [markdown]
# <a href="https://colab.research.google.com/github/Andres3417/PROGCOM-A-2026/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
minero={"nombre":"alejandra",
        "experiencia":999999999,
        "kinket":2000000}

minero
# Out:
# {'nombre': 'alejandra', 'experiencia': 999999999, 'kinket': 2000000}

# %%
#Acceder al diccionario - claves
minero.keys()
# Out:
# dict_keys(['nombre', 'experiencia', 'kinket'])

# %%
#Acceder al diccionario - valores
minero.values()
# Out:
# dict_values(['alejandra', 999999999, 2000000])

# %%
##Acceder a un valor en particular
minero["experiencia"]
# Out:
# 999999999

# %%
#Ingresar una nueva clave:valor
minero["quest"]=[10, 7000, 500, 1000, 8000]
minero
# Out:
# {'nombre': 'alejandra',
#  'experiencia': 999999999,
#  'kinket': 2000000,
#  'quest': [10, 7000, 500, 1000, 8000]}

# %%
max(minero["quest"])
# Out:
# 8000

# %%
frutas = {
    "manzana":2500,
    "pera":1000
}
frutas
# Out:
# {'manzana': 2500, 'pera': 1000}
