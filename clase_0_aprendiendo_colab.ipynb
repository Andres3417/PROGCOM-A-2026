# %% [markdown]
# # Aprendiendon a usar print
# print () es un método que permite imprimir información en consola
#
# sintaxis
#
#
# ```
# if (condicion) == verdadera:
#    print("pasan cositas")
# else:
#    print("pasan otras cositas")
# ```
# el print () imprime lo siguiente
#
# 1. cualquier tipo de dato
# 2. cualquier metodo o funcion
# 3. concatenacion de texto
# 4. operaciones matematicas

# %% [markdown]
# ##conociendo el input
# input() es un metodo con triple funcion
# 1. declara: toda la información que ingrese con este metodo, se declara automaticamente como string.
# 2. lee : porque almacena en una variable
# 3. imprime: lo que esta en un parentsis se muestra en consola

# %% [markdown]
# ### concatenación
#
# concatenar es unir dos tipos diferentes de datos

# %%
x = int(input("ingrese su edad: "))
y = input("ingrese su nombre: ")
print(y, "tiene una edad", x)
# Out:
# ingrese su edad: 34
# ingrese su nombre: ana
# ana tiene una edad 34

# %%
print(y+" tiene una edad "+str(x))
# Out:
# ana tiene una edad 34

# %%
print(f"{y} tiene una edad de {x}")
# Out:
# ana tiene una edad de 34
